# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img = cv2.imread("hello.png")
cv2.imshow(' ', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
img
# Out:
# array([[[122, 118, 119],
#         [123, 118, 119],
#         [122, 118, 118],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        [[122, 118, 119],
#         [123, 119, 120],
#         [121, 117, 117],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        [[123, 119, 120],
#         [124, 120, 121],
#         [122, 118, 118],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[ 26,  23,  21],
#         [ 27,  24,  22],
#         [ 27,  22,  23],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        [[ 25,  22,  20],
#         [ 26,  23,  21],
#         [ 26,  22,  22],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        [[ 24,  21,  19],
#         [ 25,  22,  20],
#         [ 25,  22,  21],
# ...

# %%
img1 = plt.imread("hello.png")
plt.imshow(img1)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid = cv2.VideoCapture(0)

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened()
# Out:
# True

# %%
k = vid.read()

# %%
type(k), len(k)
# Out:
# (tuple, 2)

# %%
k[0]
# Out:
# True

# %%
k
# Out:
# (True,
#  array([[[116, 121, 116],
#          [129, 128, 122],
#          [134, 126, 120],
#          ...,
#          [166, 166, 157],
#          [184, 183, 176],
#          [158, 157, 151]],
#
#         [[126, 129, 124],
#          [128, 128, 123],
#          [131, 128, 123],
#          ...,
#          [166, 166, 157],
#          [184, 183, 176],
#          [158, 157, 151]],
#
#         [[126, 128, 128],
#          [127, 128, 127],
#          [127, 127, 125],
#          ...,
#          [166, 168, 157],
#          [176, 178, 169],
#          [163, 165, 156]],
#
#         ...,
#
#         [[ 51,  35,  36],
#          [ 57,  35,  37],
#          [ 63,  35,  37],
#          ...,
#          [ 89,  75,  72],
#          [ 86,  71,  66],
#          [ 85,  70,  64]],
#
#         [[ 46,  29,  35],
#          [ 53,  29,  33],
#          [ 59,  29,  31],
#          ...,
#          [ 84,  73,  73],
#          [ 82,  70,  71],
#          [ 82,  70,  71]],
#
#         [[ 42,  36,  39],
# ...

# %%
flag, img = vid.read()

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
img = img[:,:,::-1]

# %%
if flag:
    plt.imshow(img)

# %%
for i in range(100):
    flag, img = vid.read() 
    if flag:
        plt.imshow(img[:,:,::-1])

# %%
for i in range(1000):
    flag, img = vid.read() 
    if flag:
        cv2.imshow("Preview", img)
        cv2.waitKey(1)

# %%
import cv2 as cv
